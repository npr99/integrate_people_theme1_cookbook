# %% [markdown]
# # Explore Integrated People with Air Theme 1
# Look at ANOVAs and descriptive statistics for joined data

# %% [markdown]
# ## Description of Program
# - program:    ip1_3bv1_peopleair
# - task:       Explore integrated people and air data
# - Version:    2025-12-19
# - project:    Southeast Texas Urban Integrated Field Lab
# - funding:	  DOE
# - author:     Nathanael Rosenheim

# %% [markdown]
# ## Step 0: Good Housekeeping

# %%
# 1. Import all packages
import pandas as pd     # For obtaining and cleaning tabular data
import geopandas as gpd # For obtaining and cleaning spatial data
import matplotlib.pyplot as plt # For plotting
import contextily as ctx # For adding basemaps
import numpy as np
from scipy import stats
import os # For saving output to path
import zipfile # For handling zip files
import io # For handling in-memory data
import requests # For downloading data
import rasterio # For reading geotiff files

# %%
# 2. Check versions
import sys
print("Python Version     ", sys.version)
print("geopandas version: ", gpd.__version__)
# Out:
# Python Version      3.13.9 | packaged by conda-forge | (main, Oct 22 2025, 23:12:41) [MSC v.1944 64 bit (AMD64)]
# geopandas version:  1.1.1

# %%
# 3. Check working directory
# Get information on current working directory (getcwd)
os.getcwd()
# Out:
# 'c:\\Users\\nathanael99\\MyProjects\\GitHub\\integrate_people_theme1_cookbook'

# %%
#4. Store Program Name for output files to have the same name
programname = "ip1_3bv2_peopleair"
# Make directory to save output
if not os.path.exists(programname):
    os.mkdir(programname)

# %%
# Auto-reload modules when they change (useful during development)
# %reload_ext autoreload
# %autoreload 2

# read in functions from ip1_3bv1_peopleair.py
from ip1_3bv1_peopleair import *

# %% [markdown]
# # Step 1: Obtain Data
# Obtain data from clean data step

# %%
# read in cleaned air data from ip1_2av1_convertairtocsv
source_programname = "ip1_2av1_joinpeopleair"
source_filename = f"{source_programname}.csv"

hua_ari_df = pd.read_csv(os.path.join(source_programname, source_filename))
# Out:
# C:\Users\nathanael99\AppData\Local\Temp\ipykernel_21644\2341540361.py:5: DtypeWarning: Columns (20,23,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   hua_ari_df = pd.read_csv(os.path.join(source_programname, source_filename))

# %%
hua_ari_df.head(1)
# Out:
#                    huid        Block2020          blockid          bgid  \
# 0  B481990302002008H002  481990302002008  481990302002008  481990302002
#
#        tractid  FIPScounty  numprec  ownershp  race  hispan  ...  \
# 0  48199030200     48199.0      0.0       NaN   NaN     NaN  ...
#
#    uifl_4km_Xylenes_p98  uifl_4km_Xylenes_mean  uifl_4km_Xylenes_p75  \
# 0              0.061573               0.011893              0.015375
#
#    uifl_4km_Xylenes_p25  uifl_4km_Xylenes_p90  uifl_4km_Xylenes_p95  \
# 0              0.001948              0.029066               0.04408
#
#    Household Income Group Tenure Status  Low Income Renter Status  \
# 0                     NaN           NaN                       NaN
#
#    Race Ethnicity
# 0             NaN
#
# [1 rows x 205 columns]

# %% [markdown]
# # Step 2: Clean Data

# %% [markdown]
# # Step 3: Explore Data

# %%
# Compare multiple species across percentiles (matched cases only, quiet)
species_list = ['Benzene','Styrene','Ethylene Oxide']  # Add more species as available in your data
percentile_list = ['p25','p50','p75','p90','p95','p99','p100']
results_multi_species = compare_resolution_anova(
    hua_ari_df, species_list, percentiles=percentile_list, 
    matched_cases_only=True, verbose=True)
# Out:
# === MULTI-SPECIES RESOLUTION COMPARISON ANALYSIS ===
# Species: ['Benzene', 'Styrene', 'Ethylene Oxide']
# Analysis type: Matched cases
# Percentiles: ['p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'p100']
# Note: Zero values excluded as they represent areas outside the pollution model domain
#
# ================================================================================
# PROCESSING SPECIES: BENZENE
# ================================================================================
#
# ============================================================
# ANALYSIS - BENZENE P25 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Benzene p25 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0101 ppb
#   Std:  0.0036 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0116 ppb
#   Std:  0.0050 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 8543.0949, p-value: 0.000000
# Cohen's d: -0.3407 (small)
# Cohen's d 95% CI: [-0.3514, -0.3304]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - BENZENE P50 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Benzene p50 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0211 ppb
#   Std:  0.0060 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0231 ppb
#   Std:  0.0077 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 5993.0652, p-value: 0.000000
# Cohen's d: -0.2853 (small)
# Cohen's d 95% CI: [-0.2943, -0.2764]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - BENZENE P75 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Benzene p75 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0421 ppb
#   Std:  0.0109 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0443 ppb
#   Std:  0.0130 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 2496.8917, p-value: 0.000000
# Cohen's d: -0.1842 (negligible)
# Cohen's d 95% CI: [-0.1919, -0.1769]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - BENZENE P90 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Benzene p90 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0749 ppb
#   Std:  0.0193 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0753 ppb
#   Std:  0.0205 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 39.3662, p-value: 0.000000
# Cohen's d: -0.0231 (negligible)
# Cohen's d 95% CI: [-0.0304, -0.0163]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - BENZENE P95 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Benzene p95 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.1029 ppb
#   Std:  0.0265 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.1004 ppb
#   Std:  0.0246 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 734.4111, p-value: 0.000000
# Cohen's d: 0.0999 (negligible)
# Cohen's d 95% CI: [0.0926, 0.1068]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 1km > 4km
#
# ============================================================
# ANALYSIS - BENZENE P99 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Benzene p99 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.1748 ppb
#   Std:  0.0401 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.1627 ppb
#   Std:  0.0293 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 8719.7744, p-value: 0.000000
# Cohen's d: 0.3442 (small)
# Cohen's d 95% CI: [0.3372, 0.3511]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 1km > 4km
#
# ============================================================
# ANALYSIS - BENZENE P100 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Benzene p100 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.5943 ppb
#   Std:  0.6114 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.5733 ppb
#   Std:  0.3723 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 125.9058, p-value: 0.000000
# Cohen's d: 0.0414 (negligible)
# Cohen's d 95% CI: [0.0353, 0.0473]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 1km > 4km
#
# ================================================================================
# SUMMARY TABLE - BENZENE RESOLUTION COMPARISON
# ================================================================================
# percentile  n_1km  n_4km  cohens_d  ci_low  ci_high  p_value
#        p25 147237 147237   -0.3407 -0.3514  -0.3304      0.0
#        p50 147237 147237   -0.2853 -0.2943  -0.2764      0.0
#        p75 147237 147237   -0.1842 -0.1919  -0.1769      0.0
#        p90 147237 147237   -0.0231 -0.0304  -0.0163      0.0
#        p95 147237 147237    0.0999  0.0926   0.1068      0.0
#        p99 147237 147237    0.3442  0.3372   0.3511      0.0
#       p100 147237 147237    0.0414  0.0353   0.0473      0.0
#
# ================================================================================
# PROCESSING SPECIES: STYRENE
# ================================================================================
#
# ============================================================
# ANALYSIS - STYRENE P25 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Styrene p25 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0004 ppb
#   Std:  0.0017 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0005 ppb
#   Std:  0.0011 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 439.9646, p-value: 0.000000
# Cohen's d: -0.0773 (negligible)
# Cohen's d 95% CI: [-0.0923, -0.0642]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - STYRENE P50 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Styrene p50 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0015 ppb
#   Std:  0.0034 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0019 ppb
#   Std:  0.0030 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 800.7724, p-value: 0.000000
# Cohen's d: -0.1043 (negligible)
# Cohen's d 95% CI: [-0.1157, -0.0931]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - STYRENE P75 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Styrene p75 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0044 ppb
#   Std:  0.0073 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0052 ppb
#   Std:  0.0071 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 805.2346, p-value: 0.000000
# Cohen's d: -0.1046 (negligible)
# Cohen's d 95% CI: [-0.1134, -0.0950]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - STYRENE P90 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Styrene p90 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0118 ppb
#   Std:  0.0167 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0129 ppb
#   Std:  0.0149 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 414.6618, p-value: 0.000000
# Cohen's d: -0.0751 (negligible)
# Cohen's d 95% CI: [-0.0828, -0.0670]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - STYRENE P95 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Styrene p95 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0247 ppb
#   Std:  0.0313 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0250 ppb
#   Std:  0.0255 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 4.5850, p-value: 0.032254
# Cohen's d: -0.0079 (negligible)
# Cohen's d 95% CI: [-0.0149, -0.0010]
# Levene's p-value: 0.040994 (Unequal variances)
# Welch's t-test p-value: 0.032254
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - STYRENE P99 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Styrene p99 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0741 ppb
#   Std:  0.0830 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0606 ppb
#   Std:  0.0526 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 2773.0423, p-value: 0.000000
# Cohen's d: 0.1941 (negligible)
# Cohen's d 95% CI: [0.1875, 0.2002]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 1km > 4km
#
# ============================================================
# ANALYSIS - STYRENE P100 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Styrene p100 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.2173 ppb
#   Std:  0.2176 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.1712 ppb
#   Std:  0.1318 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 4822.0913, p-value: 0.000000
# Cohen's d: 0.2559 (small)
# Cohen's d 95% CI: [0.2496, 0.2617]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 1km > 4km
#
# ================================================================================
# SUMMARY TABLE - STYRENE RESOLUTION COMPARISON
# ================================================================================
# percentile  n_1km  n_4km  cohens_d  ci_low  ci_high  p_value
#        p25 147237 147237   -0.0773 -0.0923  -0.0642   0.0000
#        p50 147237 147237   -0.1043 -0.1157  -0.0931   0.0000
#        p75 147237 147237   -0.1046 -0.1134  -0.0950   0.0000
#        p90 147237 147237   -0.0751 -0.0828  -0.0670   0.0000
#        p95 147237 147237   -0.0079 -0.0149  -0.0010   0.0323
#        p99 147237 147237    0.1941  0.1875   0.2002   0.0000
#       p100 147237 147237    0.2559  0.2496   0.2617   0.0000
#
# ================================================================================
# PROCESSING SPECIES: ETHYLENE OXIDE
# ================================================================================
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P25 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Ethylene Oxide p25 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0000 ppb
#   Std:  0.0001 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0002 ppb
#   Std:  0.0008 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 4778.3029, p-value: 0.000000
# Cohen's d: -0.2548 (small)
# Cohen's d 95% CI: [-0.2586, -0.2507]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P50 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Ethylene Oxide p50 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0000 ppb
#   Std:  0.0004 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0003 ppb
#   Std:  0.0012 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 5338.2169, p-value: 0.000000
# Cohen's d: -0.2693 (small)
# Cohen's d 95% CI: [-0.2764, -0.2618]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P75 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Ethylene Oxide p75 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0003 ppb
#   Std:  0.0014 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0009 ppb
#   Std:  0.0025 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 5749.4145, p-value: 0.000000
# Cohen's d: -0.2795 (small)
# Cohen's d 95% CI: [-0.2872, -0.2719]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P90 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Ethylene Oxide p90 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0025 ppb
#   Std:  0.0049 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0038 ppb
#   Std:  0.0061 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 3995.1071, p-value: 0.000000
# Cohen's d: -0.2330 (small)
# Cohen's d 95% CI: [-0.2404, -0.2261]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P95 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Ethylene Oxide p95 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0074 ppb
#   Std:  0.0097 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0083 ppb
#   Std:  0.0104 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 613.6679, p-value: 0.000000
# Cohen's d: -0.0913 (negligible)
# Cohen's d 95% CI: [-0.0985, -0.0846]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 4km > 1km
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P99 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Ethylene Oxide p99 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0257 ppb
#   Std:  0.0280 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0223 ppb
#   Std:  0.0214 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1368.7962, p-value: 0.000000
# Cohen's d: 0.1364 (negligible)
# Cohen's d 95% CI: [0.1291, 0.1427]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 1km > 4km
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P100 1KM vs 4KM RESOLUTION
# ============================================================
# Sample: 147,237 matched housing units
#
# --- Descriptive Statistics for Ethylene Oxide p100 by Resolution ---
# 1km Resolution (n=147,237):
#   Mean: 0.0899 ppb
#   Std:  0.0833 ppb
# 4km Resolution (n=147,237):
#   Mean: 0.0699 ppb
#   Std:  0.0520 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 6102.7023, p-value: 0.000000
# Cohen's d: 0.2879 (small)
# Cohen's d 95% CI: [0.2812, 0.2942]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: 1km > 4km
#
# ================================================================================
# SUMMARY TABLE - ETHYLENE OXIDE RESOLUTION COMPARISON
# ================================================================================
# percentile  n_1km  n_4km  cohens_d  ci_low  ci_high  p_value
#        p25 147237 147237   -0.2548 -0.2586  -0.2507      0.0
#        p50 147237 147237   -0.2693 -0.2764  -0.2618      0.0
#        p75 147237 147237   -0.2795 -0.2872  -0.2719      0.0
#        p90 147237 147237   -0.2330 -0.2404  -0.2261      0.0
#        p95 147237 147237   -0.0913 -0.0985  -0.0846      0.0
#        p99 147237 147237    0.1364  0.1291   0.1427      0.0
#       p100 147237 147237    0.2879  0.2812   0.2942      0.0
#
# ====================================================================================================
# OVERALL SUMMARY - ALL SPECIES RESOLUTION COMPARISON
# ====================================================================================================
#
# Benzene:
# percentile  cohens_d  ci_low  ci_high  p_value effect_size
#        p25   -0.3407 -0.3514  -0.3304      0.0       small
#        p50   -0.2853 -0.2943  -0.2764      0.0       small
#        p75   -0.1842 -0.1919  -0.1769      0.0  negligible
#        p90   -0.0231 -0.0304  -0.0163      0.0  negligible
#        p95    0.0999  0.0926   0.1068      0.0  negligible
#        p99    0.3442  0.3372   0.3511      0.0       small
#       p100    0.0414  0.0353   0.0473      0.0  negligible
#
# Styrene:
# percentile  cohens_d  ci_low  ci_high  p_value effect_size
#        p25   -0.0773 -0.0923  -0.0642   0.0000  negligible
#        p50   -0.1043 -0.1157  -0.0931   0.0000  negligible
#        p75   -0.1046 -0.1134  -0.0950   0.0000  negligible
#        p90   -0.0751 -0.0828  -0.0670   0.0000  negligible
#        p95   -0.0079 -0.0149  -0.0010   0.0323  negligible
#        p99    0.1941  0.1875   0.2002   0.0000  negligible
#       p100    0.2559  0.2496   0.2617   0.0000       small
#
# Ethylene Oxide:
# percentile  cohens_d  ci_low  ci_high  p_value effect_size
#        p25   -0.2548 -0.2586  -0.2507      0.0       small
#        p50   -0.2693 -0.2764  -0.2618      0.0       small
#        p75   -0.2795 -0.2872  -0.2719      0.0       small
#        p90   -0.2330 -0.2404  -0.2261      0.0       small
#        p95   -0.0913 -0.0985  -0.0846      0.0  negligible
#        p99    0.1364  0.1291   0.1427      0.0  negligible
#       p100    0.2879  0.2812   0.2942      0.0       small

# %%
results_multi_species.head(10)
# Out:
#    species percentile  matched_cases   n_1km   n_4km  mean_1km  mean_4km  \
# 0  Benzene        p25           True  147237  147237  0.010138  0.011617
# 1  Benzene        p50           True  147237  147237  0.021081  0.023051
# 2  Benzene        p75           True  147237  147237  0.042096  0.044300
# 3  Benzene        p90           True  147237  147237  0.074879  0.075339
# 4  Benzene        p95           True  147237  147237  0.102914  0.100357
# 5  Benzene        p99           True  147237  147237  0.174829  0.162740
# 6  Benzene       p100           True  147237  147237  0.594253  0.573318
# 7  Styrene        p25           True  147237  147237  0.000411  0.000524
# 8  Styrene        p50           True  147237  147237  0.001537  0.001867
# 9  Styrene        p75           True  147237  147237  0.004443  0.005198
#
#    f_statistic        p_value  cohens_d    ci_low   ci_high effect_size  \
# 0  8543.094894   0.000000e+00 -0.340655 -0.351358 -0.330407       small
# 1  5993.065244   0.000000e+00 -0.285319 -0.294323 -0.276361       small
# 2  2496.891657   0.000000e+00 -0.184165 -0.191922 -0.176889  negligible
# 3    39.366205   3.518109e-10 -0.023124 -0.030400 -0.016335  negligible
# 4   734.411131  1.556345e-161  0.099879  0.092628  0.106833  negligible
# 5  8719.774437   0.000000e+00  0.344159  0.337152  0.351092       small
# 6   125.905815   3.268655e-29  0.041355  0.035344  0.047339  negligible
# 7   439.964589   1.299498e-97 -0.077306 -0.092339 -0.064221  negligible
# 8   800.772411  6.319965e-176 -0.104294 -0.115734 -0.093123  negligible
# 9   805.234595  6.810802e-177 -0.104585 -0.113355 -0.095000  negligible
#
#          welch_p
# 0   0.000000e+00
# 1   0.000000e+00
# 2   0.000000e+00
# 3   3.518126e-10
# 4  1.560116e-161
# 5   0.000000e+00
# 6   3.278076e-29
# 7   1.331789e-97
# 8  6.375728e-176
# 9  6.814116e-177

# %%
# Compare ownership groups for Benzene at 1km resolution
species_list = ['Benzene','Styrene','Ethylene Oxide']  # Add more species as available in your data
percentile_list = ['p25','p50','p75','p90','p95','p99','p100']
results_ownership_1km = compare_groupby_anova(
    hua_ari_df, species_list, percentiles=percentile_list, 
    groupby_variable='ownershp', resolution='1km', 
    matched_cases_only=True, verbose=True
)
# Out:
# === MULTI-SPECIES GROUPBY COMPARISON ANALYSIS ===
# Species: ['Benzene', 'Styrene', 'Ethylene Oxide']
# Resolution: 1km
# Groupby variable: ownershp
# Analysis type: Matched cases
# Percentiles: ['p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'p100']
# Note: Zero values excluded as they represent areas outside the pollution model domain
# Group values found: [np.float64(1.0), np.float64(2.0)]
#
# ================================================================================
# PROCESSING SPECIES: BENZENE
# ================================================================================
#
# ============================================================
# ANALYSIS - BENZENE P25 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Benzene p25 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0100 ppb
#   Std:  0.0038 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0104 ppb
#   Std:  0.0031 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 442.5093, p-value: 0.000000
# Cohen's d: -0.1218 (negligible)
# Cohen's d 95% CI: [-0.1359, -0.1082]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P50 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Benzene p50 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0207 ppb
#   Std:  0.0061 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0217 ppb
#   Std:  0.0052 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 869.6025, p-value: 0.000000
# Cohen's d: -0.1708 (negligible)
# Cohen's d 95% CI: [-0.1851, -0.1567]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P75 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Benzene p75 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0413 ppb
#   Std:  0.0110 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0432 ppb
#   Std:  0.0099 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1016.5058, p-value: 0.000000
# Cohen's d: -0.1846 (negligible)
# Cohen's d 95% CI: [-0.1976, -0.1714]
# Levene's p-value: 0.349424 (Equal variances)
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P90 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Benzene p90 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0734 ppb
#   Std:  0.0193 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0769 ppb
#   Std:  0.0183 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1013.7970, p-value: 0.000000
# Cohen's d: -0.1844 (negligible)
# Cohen's d 95% CI: [-0.1963, -0.1727]
# Levene's p-value: 0.000020 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P95 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Benzene p95 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.1009 ppb
#   Std:  0.0265 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.1056 ppb
#   Std:  0.0253 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 972.6758, p-value: 0.000000
# Cohen's d: -0.1806 (negligible)
# Cohen's d 95% CI: [-0.1923, -0.1688]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P99 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Benzene p99 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.1725 ppb
#   Std:  0.0404 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.1776 ppb
#   Std:  0.0383 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 489.8978, p-value: 0.000000
# Cohen's d: -0.1282 (negligible)
# Cohen's d 95% CI: [-0.1397, -0.1169]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P100 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Benzene p100 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.6105 ppb
#   Std:  0.6358 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.5682 ppb
#   Std:  0.5772 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 140.6581, p-value: 0.000000
# Cohen's d: 0.0687 (negligible)
# Cohen's d 95% CI: [0.0572, 0.0797]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ================================================================================
# SUMMARY TABLE - BENZENE GROUPBY COMPARISON
# ================================================================================
# percentile  group1  group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25     1.0     2.0     83166     46486   -0.1218 -0.1359  -0.1082      0.0
#        p50     1.0     2.0     83166     46486   -0.1708 -0.1851  -0.1567      0.0
#        p75     1.0     2.0     83166     46486   -0.1846 -0.1976  -0.1714      0.0
#        p90     1.0     2.0     83166     46486   -0.1844 -0.1963  -0.1727      0.0
#        p95     1.0     2.0     83166     46486   -0.1806 -0.1923  -0.1688      0.0
#        p99     1.0     2.0     83166     46486   -0.1282 -0.1397  -0.1169      0.0
#       p100     1.0     2.0     83166     46486    0.0687  0.0572   0.0797      0.0
#
# ================================================================================
# PROCESSING SPECIES: STYRENE
# ================================================================================
#
# ============================================================
# ANALYSIS - STYRENE P25 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Styrene p25 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0004 ppb
#   Std:  0.0018 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0004 ppb
#   Std:  0.0009 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 2.4088, p-value: 0.120660
# Cohen's d: -0.0090 (negligible)
# Cohen's d 95% CI: [-0.0208, 0.0003]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.066705
# Result: No significant difference (p >= 0.05)
#
# ============================================================
# ANALYSIS - STYRENE P50 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Styrene p50 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0015 ppb
#   Std:  0.0036 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0016 ppb
#   Std:  0.0024 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 20.4315, p-value: 0.000006
# Cohen's d: -0.0262 (negligible)
# Cohen's d 95% CI: [-0.0379, -0.0156]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000001
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P75 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Styrene p75 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0044 ppb
#   Std:  0.0079 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0046 ppb
#   Std:  0.0059 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 12.5995, p-value: 0.000386
# Cohen's d: -0.0206 (negligible)
# Cohen's d 95% CI: [-0.0315, -0.0106]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000118
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P90 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Styrene p90 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0121 ppb
#   Std:  0.0183 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0115 ppb
#   Std:  0.0137 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 33.8467, p-value: 0.000000
# Cohen's d: 0.0337 (negligible)
# Cohen's d 95% CI: [0.0228, 0.0436]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - STYRENE P95 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Styrene p95 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0254 ppb
#   Std:  0.0342 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0244 ppb
#   Std:  0.0268 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 26.6868, p-value: 0.000000
# Cohen's d: 0.0299 (negligible)
# Cohen's d 95% CI: [0.0192, 0.0402]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - STYRENE P99 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Styrene p99 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0749 ppb
#   Std:  0.0875 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0754 ppb
#   Std:  0.0783 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 0.8160, p-value: 0.366345
# Cohen's d: -0.0052 (negligible)
# Cohen's d 95% CI: [-0.0166, 0.0058]
# Levene's p-value: 0.010792 (Unequal variances)
# Welch's t-test p-value: 0.351335
# Result: No significant difference (p >= 0.05)
#
# ============================================================
# ANALYSIS - STYRENE P100 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Styrene p100 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.2212 ppb
#   Std:  0.2307 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.2148 ppb
#   Std:  0.1976 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 25.1983, p-value: 0.000001
# Cohen's d: 0.0291 (negligible)
# Cohen's d 95% CI: [0.0174, 0.0398]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ================================================================================
# SUMMARY TABLE - STYRENE GROUPBY COMPARISON
# ================================================================================
# percentile  group1  group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25     1.0     2.0     83166     46486   -0.0090 -0.0208   0.0003   0.1207
#        p50     1.0     2.0     83166     46486   -0.0262 -0.0379  -0.0156   0.0000
#        p75     1.0     2.0     83166     46486   -0.0206 -0.0315  -0.0106   0.0004
#        p90     1.0     2.0     83166     46486    0.0337  0.0228   0.0436   0.0000
#        p95     1.0     2.0     83166     46486    0.0299  0.0192   0.0402   0.0000
#        p99     1.0     2.0     83166     46486   -0.0052 -0.0166   0.0058   0.3663
#       p100     1.0     2.0     83166     46486    0.0291  0.0174   0.0398   0.0000
#
# ================================================================================
# PROCESSING SPECIES: ETHYLENE OXIDE
# ================================================================================
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P25 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p25 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0000 ppb
#   Std:  0.0000 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0000 ppb
#   Std:  0.0001 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 28.4808, p-value: 0.000000
# Cohen's d: 0.0309 (negligible)
# Cohen's d 95% CI: [0.0162, 0.0517]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000001
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P50 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p50 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0000 ppb
#   Std:  0.0003 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0000 ppb
#   Std:  0.0004 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 18.5565, p-value: 0.000017
# Cohen's d: 0.0249 (negligible)
# Cohen's d 95% CI: [0.0114, 0.0419]
# Levene's p-value: 0.000007 (Unequal variances)
# Welch's t-test p-value: 0.000065
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P75 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p75 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0004 ppb
#   Std:  0.0015 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0003 ppb
#   Std:  0.0012 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 242.4384, p-value: 0.000000
# Cohen's d: 0.0902 (negligible)
# Cohen's d 95% CI: [0.0789, 0.1017]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P90 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p90 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0027 ppb
#   Std:  0.0055 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0023 ppb
#   Std:  0.0038 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 247.8669, p-value: 0.000000
# Cohen's d: 0.0912 (negligible)
# Cohen's d 95% CI: [0.0808, 0.1010]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P95 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p95 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0076 ppb
#   Std:  0.0106 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0075 ppb
#   Std:  0.0083 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 2.6385, p-value: 0.104305
# Cohen's d: 0.0094 (negligible)
# Cohen's d 95% CI: [-0.0010, 0.0202]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.081675
# Result: No significant difference (p >= 0.05)
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P99 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p99 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0258 ppb
#   Std:  0.0292 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0264 ppb
#   Std:  0.0269 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 16.6425, p-value: 0.000045
# Cohen's d: -0.0236 (negligible)
# Cohen's d 95% CI: [-0.0349, -0.0124]
# Levene's p-value: 0.499245 (Equal variances)
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P100 1KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 83,166, Group 2.0: 46,486 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p100 by ownershp ---
# Group 1.0 (n=83,166):
#   Mean: 0.0908 ppb
#   Std:  0.0894 ppb
# Group 2.0 (n=46,486):
#   Mean: 0.0906 ppb
#   Std:  0.0757 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 0.1163, p-value: 0.733079
# Cohen's d: 0.0020 (negligible)
# Cohen's d 95% CI: [-0.0090, 0.0131]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.720864
# Result: No significant difference (p >= 0.05)
#
# ================================================================================
# SUMMARY TABLE - ETHYLENE OXIDE GROUPBY COMPARISON
# ================================================================================
# percentile  group1  group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25     1.0     2.0     83166     46486    0.0309  0.0162   0.0517   0.0000
#        p50     1.0     2.0     83166     46486    0.0249  0.0114   0.0419   0.0000
#        p75     1.0     2.0     83166     46486    0.0902  0.0789   0.1017   0.0000
#        p90     1.0     2.0     83166     46486    0.0912  0.0808   0.1010   0.0000
#        p95     1.0     2.0     83166     46486    0.0094 -0.0010   0.0202   0.1043
#        p99     1.0     2.0     83166     46486   -0.0236 -0.0349  -0.0124   0.0000
#       p100     1.0     2.0     83166     46486    0.0020 -0.0090   0.0131   0.7331
#
# ====================================================================================================
# OVERALL SUMMARY - ALL SPECIES GROUPBY COMPARISON
# ====================================================================================================
#
# Benzene:
# percentile  group1  group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25     1.0     2.0   -0.1218 -0.1359  -0.1082      0.0  negligible
#        p50     1.0     2.0   -0.1708 -0.1851  -0.1567      0.0  negligible
#        p75     1.0     2.0   -0.1846 -0.1976  -0.1714      0.0  negligible
#        p90     1.0     2.0   -0.1844 -0.1963  -0.1727      0.0  negligible
#        p95     1.0     2.0   -0.1806 -0.1923  -0.1688      0.0  negligible
#        p99     1.0     2.0   -0.1282 -0.1397  -0.1169      0.0  negligible
#       p100     1.0     2.0    0.0687  0.0572   0.0797      0.0  negligible
#
# Styrene:
# percentile  group1  group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25     1.0     2.0   -0.0090 -0.0208   0.0003   0.1207  negligible
#        p50     1.0     2.0   -0.0262 -0.0379  -0.0156   0.0000  negligible
#        p75     1.0     2.0   -0.0206 -0.0315  -0.0106   0.0004  negligible
#        p90     1.0     2.0    0.0337  0.0228   0.0436   0.0000  negligible
#        p95     1.0     2.0    0.0299  0.0192   0.0402   0.0000  negligible
#        p99     1.0     2.0   -0.0052 -0.0166   0.0058   0.3663  negligible
#       p100     1.0     2.0    0.0291  0.0174   0.0398   0.0000  negligible
#
# Ethylene Oxide:
# percentile  group1  group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25     1.0     2.0    0.0309  0.0162   0.0517   0.0000  negligible
#        p50     1.0     2.0    0.0249  0.0114   0.0419   0.0000  negligible
#        p75     1.0     2.0    0.0902  0.0789   0.1017   0.0000  negligible
#        p90     1.0     2.0    0.0912  0.0808   0.1010   0.0000  negligible
#        p95     1.0     2.0    0.0094 -0.0010   0.0202   0.1043  negligible
#        p99     1.0     2.0   -0.0236 -0.0349  -0.0124   0.0000  negligible
#       p100     1.0     2.0    0.0020 -0.0090   0.0131   0.7331  negligible

# %%
results_ownership_1km.head(10)
# Out:
#    species percentile resolution groupby_variable  matched_cases  group1  \
# 0  Benzene        p25        1km         ownershp           True     1.0
# 1  Benzene        p50        1km         ownershp           True     1.0
# 2  Benzene        p75        1km         ownershp           True     1.0
# 3  Benzene        p90        1km         ownershp           True     1.0
# 4  Benzene        p95        1km         ownershp           True     1.0
# 5  Benzene        p99        1km         ownershp           True     1.0
# 6  Benzene       p100        1km         ownershp           True     1.0
# 7  Styrene        p25        1km         ownershp           True     1.0
# 8  Styrene        p50        1km         ownershp           True     1.0
# 9  Styrene        p75        1km         ownershp           True     1.0
#
#    group2  n_group1  n_group2  mean_group1  mean_group2  f_statistic  \
# 0     2.0     83166     46486     0.009951     0.010380   442.509255
# 1     2.0     83166     46486     0.020657     0.021653   869.602527
# 2     2.0     83166     46486     0.041253     0.043218  1016.505752
# 3     2.0     83166     46486     0.073374     0.076868  1013.796961
# 4     2.0     83166     46486     0.100866     0.105576   972.675783
# 5     2.0     83166     46486     0.172521     0.177602   489.897781
# 6     2.0     83166     46486     0.610485     0.568214   140.658081
# 7     2.0     83166     46486     0.000403     0.000417     2.408762
# 8     2.0     83166     46486     0.001510     0.001594    20.431514
# 9     2.0     83166     46486     0.004406     0.004555    12.599549
#
#          p_value  cohens_d    ci_low   ci_high effect_size        welch_p
# 0   4.494570e-98 -0.121819 -0.135857 -0.108248  negligible  9.036207e-110
# 1  1.705697e-190 -0.170772 -0.185135 -0.156738  negligible  1.627273e-207
# 2  3.381019e-222 -0.184634 -0.197558 -0.171384  negligible            NaN
# 3  1.297950e-221 -0.184387 -0.196324 -0.172689  negligible  4.930242e-228
# 4  9.630010e-213 -0.180609 -0.192281 -0.168772  negligible  6.627973e-218
# 5  2.384250e-108 -0.128176 -0.139720 -0.116924  negligible  2.155806e-111
# 6   1.986553e-32  0.068681  0.057238  0.079749  negligible   3.810798e-34
# 7   1.206602e-01 -0.008988 -0.020751  0.000318  negligible   6.670517e-02
# 8   6.185821e-06 -0.026176 -0.037862 -0.015621  negligible   5.037609e-07
# 9   3.859762e-04 -0.020556 -0.031549 -0.010616  negligible   1.178260e-04

# %%
# Compare ownership groups for Benzene at 1km resolution
species_list = ['Benzene','Styrene','Ethylene Oxide']  # Add more species as available in your data
percentile_list = ['p25','p50','p75','p90','p95','p99','p100']
results_ownership_4km = compare_groupby_anova(
    hua_ari_df, species_list, percentiles=percentile_list, 
    groupby_variable='ownershp', resolution='4km', 
    matched_cases_only=True, verbose=True
)
# Out:
# === MULTI-SPECIES GROUPBY COMPARISON ANALYSIS ===
# Species: ['Benzene', 'Styrene', 'Ethylene Oxide']
# Resolution: 4km
# Groupby variable: ownershp
# Analysis type: Matched cases
# Percentiles: ['p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'p100']
# Note: Zero values excluded as they represent areas outside the pollution model domain
# Group values found: [np.float64(1.0), np.float64(2.0)]
#
# ================================================================================
# PROCESSING SPECIES: BENZENE
# ================================================================================
#
# ============================================================
# ANALYSIS - BENZENE P25 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Benzene p25 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0114 ppb
#   Std:  0.0042 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0118 ppb
#   Std:  0.0047 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 444.4506, p-value: 0.000000
# Cohen's d: -0.1100 (negligible)
# Cohen's d 95% CI: [-0.1202, -0.0991]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P50 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Benzene p50 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0221 ppb
#   Std:  0.0065 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0233 ppb
#   Std:  0.0074 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1209.0850, p-value: 0.000000
# Cohen's d: -0.1815 (negligible)
# Cohen's d 95% CI: [-0.1918, -0.1704]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P75 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Benzene p75 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0414 ppb
#   Std:  0.0112 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0442 ppb
#   Std:  0.0128 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 2222.5490, p-value: 0.000000
# Cohen's d: -0.2460 (small)
# Cohen's d 95% CI: [-0.2567, -0.2347]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P90 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Benzene p90 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0700 ppb
#   Std:  0.0183 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0749 ppb
#   Std:  0.0204 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 2465.9642, p-value: 0.000000
# Cohen's d: -0.2591 (small)
# Cohen's d 95% CI: [-0.2698, -0.2480]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P95 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Benzene p95 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0949 ppb
#   Std:  0.0234 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.1005 ppb
#   Std:  0.0246 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 2010.4332, p-value: 0.000000
# Cohen's d: -0.2340 (small)
# Cohen's d 95% CI: [-0.2445, -0.2231]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - BENZENE P99 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Benzene p99 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.1867 ppb
#   Std:  0.1328 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.1774 ppb
#   Std:  0.0914 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 218.6699, p-value: 0.000000
# Cohen's d: 0.0772 (negligible)
# Cohen's d 95% CI: [0.0680, 0.0857]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - BENZENE P100 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Benzene p100 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.9799 ppb
#   Std:  1.8822 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.7039 ppb
#   Std:  1.0694 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1010.3066, p-value: 0.000000
# Cohen's d: 0.1659 (negligible)
# Cohen's d 95% CI: [0.1579, 0.1737]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ================================================================================
# SUMMARY TABLE - BENZENE GROUPBY COMPARISON
# ================================================================================
# percentile  group1  group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25     1.0     2.0    113927     54187   -0.1100 -0.1202  -0.0991      0.0
#        p50     1.0     2.0    113927     54187   -0.1815 -0.1918  -0.1704      0.0
#        p75     1.0     2.0    113927     54187   -0.2460 -0.2567  -0.2347      0.0
#        p90     1.0     2.0    113927     54187   -0.2591 -0.2698  -0.2480      0.0
#        p95     1.0     2.0    113927     54187   -0.2340 -0.2445  -0.2231      0.0
#        p99     1.0     2.0    113927     54187    0.0772  0.0680   0.0857      0.0
#       p100     1.0     2.0    113927     54187    0.1659  0.1579   0.1737      0.0
#
# ================================================================================
# PROCESSING SPECIES: STYRENE
# ================================================================================
#
# ============================================================
# ANALYSIS - STYRENE P25 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Styrene p25 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0006 ppb
#   Std:  0.0016 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0007 ppb
#   Std:  0.0019 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 90.3060, p-value: 0.000000
# Cohen's d: -0.0496 (negligible)
# Cohen's d 95% CI: [-0.0597, -0.0385]
# Levene's p-value: 0.210617 (Equal variances)
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P50 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Styrene p50 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0020 ppb
#   Std:  0.0043 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0022 ppb
#   Std:  0.0048 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 134.5609, p-value: 0.000000
# Cohen's d: -0.0605 (negligible)
# Cohen's d 95% CI: [-0.0706, -0.0491]
# Levene's p-value: 0.191366 (Equal variances)
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P75 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Styrene p75 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0057 ppb
#   Std:  0.0115 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0064 ppb
#   Std:  0.0131 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 126.4987, p-value: 0.000000
# Cohen's d: -0.0587 (negligible)
# Cohen's d 95% CI: [-0.0687, -0.0478]
# Levene's p-value: 0.835160 (Equal variances)
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P90 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Styrene p90 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0135 ppb
#   Std:  0.0214 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0148 ppb
#   Std:  0.0231 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 125.9908, p-value: 0.000000
# Cohen's d: -0.0586 (negligible)
# Cohen's d 95% CI: [-0.0686, -0.0475]
# Levene's p-value: 0.076708 (Equal variances)
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P95 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Styrene p95 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0243 ppb
#   Std:  0.0310 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0276 ppb
#   Std:  0.0334 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 382.3945, p-value: 0.000000
# Cohen's d: -0.1020 (negligible)
# Cohen's d 95% CI: [-0.1122, -0.0910]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P99 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Styrene p99 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0616 ppb
#   Std:  0.0576 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0668 ppb
#   Std:  0.0623 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 279.9990, p-value: 0.000000
# Cohen's d: -0.0873 (negligible)
# Cohen's d 95% CI: [-0.0977, -0.0761]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - STYRENE P100 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Styrene p100 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.2184 ppb
#   Std:  0.3077 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.1924 ppb
#   Std:  0.1997 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 321.8206, p-value: 0.000000
# Cohen's d: 0.0936 (negligible)
# Cohen's d 95% CI: [0.0853, 0.1020]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ================================================================================
# SUMMARY TABLE - STYRENE GROUPBY COMPARISON
# ================================================================================
# percentile  group1  group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25     1.0     2.0    113927     54187   -0.0496 -0.0597  -0.0385      0.0
#        p50     1.0     2.0    113927     54187   -0.0605 -0.0706  -0.0491      0.0
#        p75     1.0     2.0    113927     54187   -0.0587 -0.0687  -0.0478      0.0
#        p90     1.0     2.0    113927     54187   -0.0586 -0.0686  -0.0475      0.0
#        p95     1.0     2.0    113927     54187   -0.1020 -0.1122  -0.0910      0.0
#        p99     1.0     2.0    113927     54187   -0.0873 -0.0977  -0.0761      0.0
#       p100     1.0     2.0    113927     54187    0.0936  0.0853   0.1020      0.0
#
# ================================================================================
# PROCESSING SPECIES: ETHYLENE OXIDE
# ================================================================================
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P25 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p25 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0001 ppb
#   Std:  0.0008 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0001 ppb
#   Std:  0.0007 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 38.9160, p-value: 0.000000
# Cohen's d: 0.0326 (negligible)
# Cohen's d 95% CI: [0.0230, 0.0422]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P50 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p50 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0002 ppb
#   Std:  0.0011 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0002 ppb
#   Std:  0.0010 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 45.0954, p-value: 0.000000
# Cohen's d: 0.0350 (negligible)
# Cohen's d 95% CI: [0.0254, 0.0448]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P75 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p75 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0008 ppb
#   Std:  0.0023 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0008 ppb
#   Std:  0.0021 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 14.6539, p-value: 0.000129
# Cohen's d: 0.0200 (negligible)
# Cohen's d 95% CI: [0.0103, 0.0296]
# Levene's p-value: 0.000077 (Unequal variances)
# Welch's t-test p-value: 0.000079
# Result: Significant difference (p < 0.05)
# Direction: Group 1.0 > Group 2.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P90 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p90 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0031 ppb
#   Std:  0.0056 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0035 ppb
#   Std:  0.0057 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 201.5674, p-value: 0.000000
# Cohen's d: -0.0741 (negligible)
# Cohen's d 95% CI: [-0.0838, -0.0632]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P95 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p95 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0065 ppb
#   Std:  0.0096 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0078 ppb
#   Std:  0.0100 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 611.5885, p-value: 0.000000
# Cohen's d: -0.1291 (negligible)
# Cohen's d 95% CI: [-0.1389, -0.1182]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P99 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p99 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0172 ppb
#   Std:  0.0199 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0207 ppb
#   Std:  0.0219 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1057.0825, p-value: 0.000000
# Cohen's d: -0.1697 (negligible)
# Cohen's d 95% CI: [-0.1798, -0.1593]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P100 4KM
# Comparing ownershp: 1.0 vs 2.0
# ============================================================
# Sample: Group 1.0: 113,927, Group 2.0: 54,187 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p100 by ownershp ---
# Group 1.0 (n=113,927):
#   Mean: 0.0532 ppb
#   Std:  0.0514 ppb
# Group 2.0 (n=54,187):
#   Mean: 0.0651 ppb
#   Std:  0.0535 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1927.6190, p-value: 0.000000
# Cohen's d: -0.2291 (small)
# Cohen's d 95% CI: [-0.2397, -0.2190]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group 2.0 > Group 1.0
#
# ================================================================================
# SUMMARY TABLE - ETHYLENE OXIDE GROUPBY COMPARISON
# ================================================================================
# percentile  group1  group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25     1.0     2.0    113927     54187    0.0326  0.0230   0.0422   0.0000
#        p50     1.0     2.0    113927     54187    0.0350  0.0254   0.0448   0.0000
#        p75     1.0     2.0    113927     54187    0.0200  0.0103   0.0296   0.0001
#        p90     1.0     2.0    113927     54187   -0.0741 -0.0838  -0.0632   0.0000
#        p95     1.0     2.0    113927     54187   -0.1291 -0.1389  -0.1182   0.0000
#        p99     1.0     2.0    113927     54187   -0.1697 -0.1798  -0.1593   0.0000
#       p100     1.0     2.0    113927     54187   -0.2291 -0.2397  -0.2190   0.0000
#
# ====================================================================================================
# OVERALL SUMMARY - ALL SPECIES GROUPBY COMPARISON
# ====================================================================================================
#
# Benzene:
# percentile  group1  group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25     1.0     2.0   -0.1100 -0.1202  -0.0991      0.0  negligible
#        p50     1.0     2.0   -0.1815 -0.1918  -0.1704      0.0  negligible
#        p75     1.0     2.0   -0.2460 -0.2567  -0.2347      0.0       small
#        p90     1.0     2.0   -0.2591 -0.2698  -0.2480      0.0       small
#        p95     1.0     2.0   -0.2340 -0.2445  -0.2231      0.0       small
#        p99     1.0     2.0    0.0772  0.0680   0.0857      0.0  negligible
#       p100     1.0     2.0    0.1659  0.1579   0.1737      0.0  negligible
#
# Styrene:
# percentile  group1  group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25     1.0     2.0   -0.0496 -0.0597  -0.0385      0.0  negligible
#        p50     1.0     2.0   -0.0605 -0.0706  -0.0491      0.0  negligible
#        p75     1.0     2.0   -0.0587 -0.0687  -0.0478      0.0  negligible
#        p90     1.0     2.0   -0.0586 -0.0686  -0.0475      0.0  negligible
#        p95     1.0     2.0   -0.1020 -0.1122  -0.0910      0.0  negligible
#        p99     1.0     2.0   -0.0873 -0.0977  -0.0761      0.0  negligible
#       p100     1.0     2.0    0.0936  0.0853   0.1020      0.0  negligible
#
# Ethylene Oxide:
# percentile  group1  group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25     1.0     2.0    0.0326  0.0230   0.0422   0.0000  negligible
#        p50     1.0     2.0    0.0350  0.0254   0.0448   0.0000  negligible
#        p75     1.0     2.0    0.0200  0.0103   0.0296   0.0001  negligible
#        p90     1.0     2.0   -0.0741 -0.0838  -0.0632   0.0000  negligible
#        p95     1.0     2.0   -0.1291 -0.1389  -0.1182   0.0000  negligible
#        p99     1.0     2.0   -0.1697 -0.1798  -0.1593   0.0000  negligible
#       p100     1.0     2.0   -0.2291 -0.2397  -0.2190   0.0000       small

# %%
results_ownership_4km.head(5)
# Out:
#    species percentile resolution groupby_variable  matched_cases  group1  \
# 0  Benzene        p25        4km         ownershp           True     1.0
# 1  Benzene        p50        4km         ownershp           True     1.0
# 2  Benzene        p75        4km         ownershp           True     1.0
# 3  Benzene        p90        4km         ownershp           True     1.0
# 4  Benzene        p95        4km         ownershp           True     1.0
#
#    group2  n_group1  n_group2  mean_group1  mean_group2  f_statistic  \
# 0     2.0    113927     54187     0.011367     0.011848   444.450623
# 1     2.0    113927     54187     0.022094     0.023334  1209.084972
# 2     2.0    113927     54187     0.041353     0.044248  2222.548966
# 3     2.0    113927     54187     0.069975     0.074898  2465.964167
# 4     2.0    113927     54187     0.094912     0.100473  2010.433157
#
#          p_value  cohens_d    ci_low   ci_high effect_size        welch_p
# 0   1.562268e-98 -0.110015 -0.120204 -0.099101  negligible   1.110355e-91
# 1  5.650495e-264 -0.181455 -0.191763 -0.170363  negligible  4.567077e-241
# 2   0.000000e+00 -0.246018 -0.256662 -0.234696       small   0.000000e+00
# 3   0.000000e+00 -0.259140 -0.269798 -0.248046       small   0.000000e+00
# 4   0.000000e+00 -0.233984 -0.244456 -0.223076       small   0.000000e+00

# %%
# describe variable Low Income Renter Status
hua_ari_df['Low Income Renter Status'].describe()
# Out:
# count                    168114
# unique                        2
# top       Not Low Income Renter
# freq                     136545
# Name: Low Income Renter Status, dtype: object

# %%
# Compare ownership groups for Benzene at 1km resolution
species_list = ['Benzene','Styrene','Ethylene Oxide']  # Add more species as available in your data
percentile_list = ['p25','p50','p75','p90','p95','p99','p100']
results_lowrenter_1km = compare_groupby_anova(
    hua_ari_df, species_list, percentiles=percentile_list, 
    groupby_variable='Low Income Renter Status', resolution='1km', 
    matched_cases_only=True, verbose=True
)
# Out:
# === MULTI-SPECIES GROUPBY COMPARISON ANALYSIS ===
# Species: ['Benzene', 'Styrene', 'Ethylene Oxide']
# Resolution: 1km
# Groupby variable: Low Income Renter Status
# Analysis type: Matched cases
# Percentiles: ['p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'p100']
# Note: Zero values excluded as they represent areas outside the pollution model domain
# Group values found: ['Low Income Renter', 'Not Low Income Renter']
#
# ================================================================================
# PROCESSING SPECIES: BENZENE
# ================================================================================
#
# ============================================================
# ANALYSIS - BENZENE P25 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Benzene p25 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0104 ppb
#   Std:  0.0027 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0100 ppb
#   Std:  0.0037 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 278.5697, p-value: 0.000000
# Cohen's d: 0.1140 (negligible)
# Cohen's d 95% CI: [0.0999, 0.1287]
# Levene's p-value: 0.000112 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Low Income Renter > Group Not Low Income Renter
#
# ============================================================
# ANALYSIS - BENZENE P50 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Benzene p50 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0218 ppb
#   Std:  0.0049 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0208 ppb
#   Std:  0.0060 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 676.5921, p-value: 0.000000
# Cohen's d: 0.1776 (negligible)
# Cohen's d 95% CI: [0.1632, 0.1933]
# Levene's p-value: 0.017290 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Low Income Renter > Group Not Low Income Renter
#
# ============================================================
# ANALYSIS - BENZENE P75 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Benzene p75 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0436 ppb
#   Std:  0.0098 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0415 ppb
#   Std:  0.0109 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 820.7429, p-value: 0.000000
# Cohen's d: 0.1957 (negligible)
# Cohen's d 95% CI: [0.1809, 0.2108]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Low Income Renter > Group Not Low Income Renter
#
# ============================================================
# ANALYSIS - BENZENE P90 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Benzene p90 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0776 ppb
#   Std:  0.0186 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0738 ppb
#   Std:  0.0191 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 852.6772, p-value: 0.000000
# Cohen's d: 0.1994 (negligible)
# Cohen's d 95% CI: [0.1854, 0.2138]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Low Income Renter > Group Not Low Income Renter
#
# ============================================================
# ANALYSIS - BENZENE P95 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Benzene p95 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.1066 ppb
#   Std:  0.0259 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.1015 ppb
#   Std:  0.0261 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 830.7310, p-value: 0.000000
# Cohen's d: 0.1968 (negligible)
# Cohen's d 95% CI: [0.1831, 0.2112]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Low Income Renter > Group Not Low Income Renter
#
# ============================================================
# ANALYSIS - BENZENE P99 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Benzene p99 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.1792 ppb
#   Std:  0.0391 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.1731 ppb
#   Std:  0.0398 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 512.0933, p-value: 0.000000
# Cohen's d: 0.1545 (negligible)
# Cohen's d 95% CI: [0.1409, 0.1689]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Low Income Renter > Group Not Low Income Renter
#
# ============================================================
# ANALYSIS - BENZENE P100 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Benzene p100 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.5551 ppb
#   Std:  0.4891 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.6060 ppb
#   Std:  0.6447 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 146.3976, p-value: 0.000000
# Cohen's d: -0.0826 (negligible)
# Cohen's d 95% CI: [-0.0938, -0.0706]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ================================================================================
# SUMMARY TABLE - BENZENE GROUPBY COMPARISON
# ================================================================================
# percentile            group1                group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25 Low Income Renter Not Low Income Renter     27108    102544    0.1140  0.0999   0.1287      0.0
#        p50 Low Income Renter Not Low Income Renter     27108    102544    0.1776  0.1632   0.1933      0.0
#        p75 Low Income Renter Not Low Income Renter     27108    102544    0.1957  0.1809   0.2108      0.0
#        p90 Low Income Renter Not Low Income Renter     27108    102544    0.1994  0.1854   0.2138      0.0
#        p95 Low Income Renter Not Low Income Renter     27108    102544    0.1968  0.1831   0.2112      0.0
#        p99 Low Income Renter Not Low Income Renter     27108    102544    0.1545  0.1409   0.1689      0.0
#       p100 Low Income Renter Not Low Income Renter     27108    102544   -0.0826 -0.0938  -0.0706      0.0
#
# ================================================================================
# PROCESSING SPECIES: STYRENE
# ================================================================================
#
# ============================================================
# ANALYSIS - STYRENE P25 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Styrene p25 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0004 ppb
#   Std:  0.0010 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0004 ppb
#   Std:  0.0017 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 1.4543, p-value: 0.227845
# Cohen's d: 0.0082 (negligible)
# Cohen's d 95% CI: [-0.0017, 0.0195]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.119817
# Result: No significant difference (p >= 0.05)
#
# ============================================================
# ANALYSIS - STYRENE P50 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Styrene p50 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0016 ppb
#   Std:  0.0024 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0015 ppb
#   Std:  0.0034 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 3.4908, p-value: 0.061714
# Cohen's d: 0.0128 (negligible)
# Cohen's d 95% CI: [0.0022, 0.0244]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.022041
# Result: No significant difference (p >= 0.05)
#
# ============================================================
# ANALYSIS - STYRENE P75 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Styrene p75 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0045 ppb
#   Std:  0.0055 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0045 ppb
#   Std:  0.0076 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 0.0025, p-value: 0.960331
# Cohen's d: -0.0003 (negligible)
# Cohen's d 95% CI: [-0.0113, 0.0108]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.952253
# Result: No significant difference (p >= 0.05)
#
# ============================================================
# ANALYSIS - STYRENE P90 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Styrene p90 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0111 ppb
#   Std:  0.0126 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0121 ppb
#   Std:  0.0177 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 71.9004, p-value: 0.000000
# Cohen's d: -0.0579 (negligible)
# Cohen's d 95% CI: [-0.0689, -0.0474]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - STYRENE P95 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Styrene p95 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0236 ppb
#   Std:  0.0248 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0254 ppb
#   Std:  0.0334 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 71.5264, p-value: 0.000000
# Cohen's d: -0.0578 (negligible)
# Cohen's d 95% CI: [-0.0694, -0.0468]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - STYRENE P99 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Styrene p99 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0732 ppb
#   Std:  0.0749 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0756 ppb
#   Std:  0.0866 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 16.9852, p-value: 0.000038
# Cohen's d: -0.0281 (negligible)
# Cohen's d 95% CI: [-0.0404, -0.0156]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000007
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - STYRENE P100 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Styrene p100 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.2092 ppb
#   Std:  0.1815 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.2214 ppb
#   Std:  0.2284 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 67.1139, p-value: 0.000000
# Cohen's d: -0.0559 (negligible)
# Cohen's d 95% CI: [-0.0679, -0.0444]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ================================================================================
# SUMMARY TABLE - STYRENE GROUPBY COMPARISON
# ================================================================================
# percentile            group1                group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25 Low Income Renter Not Low Income Renter     27108    102544    0.0082 -0.0017   0.0195   0.2278
#        p50 Low Income Renter Not Low Income Renter     27108    102544    0.0128  0.0022   0.0244   0.0617
#        p75 Low Income Renter Not Low Income Renter     27108    102544   -0.0003 -0.0113   0.0108   0.9603
#        p90 Low Income Renter Not Low Income Renter     27108    102544   -0.0579 -0.0689  -0.0474   0.0000
#        p95 Low Income Renter Not Low Income Renter     27108    102544   -0.0578 -0.0694  -0.0468   0.0000
#        p99 Low Income Renter Not Low Income Renter     27108    102544   -0.0281 -0.0404  -0.0156   0.0000
#       p100 Low Income Renter Not Low Income Renter     27108    102544   -0.0559 -0.0679  -0.0444   0.0000
#
# ================================================================================
# PROCESSING SPECIES: ETHYLENE OXIDE
# ================================================================================
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P25 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p25 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0000 ppb
#   Std:  0.0001 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0000 ppb
#   Std:  0.0000 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 25.4496, p-value: 0.000000
# Cohen's d: -0.0345 (negligible)
# Cohen's d 95% CI: [-0.0533, -0.0171]
# Levene's p-value: 0.000001 (Unequal variances)
# Welch's t-test p-value: 0.000006
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P50 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p50 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0000 ppb
#   Std:  0.0004 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0000 ppb
#   Std:  0.0003 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 22.8719, p-value: 0.000002
# Cohen's d: -0.0327 (negligible)
# Cohen's d 95% CI: [-0.0495, -0.0158]
# Levene's p-value: 0.000001 (Unequal variances)
# Welch's t-test p-value: 0.000013
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P75 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p75 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0002 ppb
#   Std:  0.0011 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0004 ppb
#   Std:  0.0014 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 218.0572, p-value: 0.000000
# Cohen's d: -0.1008 (negligible)
# Cohen's d 95% CI: [-0.1128, -0.0884]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P90 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p90 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0022 ppb
#   Std:  0.0034 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0027 ppb
#   Std:  0.0053 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 235.3283, p-value: 0.000000
# Cohen's d: -0.1048 (negligible)
# Cohen's d 95% CI: [-0.1145, -0.0943]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000000
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P95 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p95 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0073 ppb
#   Std:  0.0076 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0076 ppb
#   Std:  0.0104 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 13.1765, p-value: 0.000284
# Cohen's d: -0.0248 (negligible)
# Cohen's d 95% CI: [-0.0354, -0.0136]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.000016
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P99 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p99 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0262 ppb
#   Std:  0.0261 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0260 ppb
#   Std:  0.0290 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 0.9270, p-value: 0.335645
# Cohen's d: 0.0066 (negligible)
# Cohen's d 95% CI: [-0.0052, 0.0199]
# Levene's p-value: 0.003383 (Unequal variances)
# Welch's t-test p-value: 0.306394
# Result: No significant difference (p >= 0.05)
#
# ============================================================
# ANALYSIS - ETHYLENE OXIDE P100 1KM
# Comparing Low Income Renter Status: Low Income Renter vs Not Low Income Renter
# ============================================================
# Sample: Group Low Income Renter: 27,108, Group Not Low Income Renter: 102,544 housing units
#
# --- Descriptive Statistics for Ethylene Oxide p100 by Low Income Renter Status ---
# Group Low Income Renter (n=27,108):
#   Mean: 0.0897 ppb
#   Std:  0.0712 ppb
# Group Not Low Income Renter (n=102,544):
#   Mean: 0.0910 ppb
#   Std:  0.0879 ppb
#
# --- Statistical Results ---
# ANOVA F-statistic: 4.8786, p-value: 0.027193
# Cohen's d: -0.0151 (negligible)
# Cohen's d 95% CI: [-0.0270, -0.0032]
# Levene's p-value: 0.000000 (Unequal variances)
# Welch's t-test p-value: 0.012597
# Result: Significant difference (p < 0.05)
# Direction: Group Not Low Income Renter > Group Low Income Renter
#
# ================================================================================
# SUMMARY TABLE - ETHYLENE OXIDE GROUPBY COMPARISON
# ================================================================================
# percentile            group1                group2  n_group1  n_group2  cohens_d  ci_low  ci_high  p_value
#        p25 Low Income Renter Not Low Income Renter     27108    102544   -0.0345 -0.0533  -0.0171   0.0000
#        p50 Low Income Renter Not Low Income Renter     27108    102544   -0.0327 -0.0495  -0.0158   0.0000
#        p75 Low Income Renter Not Low Income Renter     27108    102544   -0.1008 -0.1128  -0.0884   0.0000
#        p90 Low Income Renter Not Low Income Renter     27108    102544   -0.1048 -0.1145  -0.0943   0.0000
#        p95 Low Income Renter Not Low Income Renter     27108    102544   -0.0248 -0.0354  -0.0136   0.0003
#        p99 Low Income Renter Not Low Income Renter     27108    102544    0.0066 -0.0052   0.0199   0.3356
#       p100 Low Income Renter Not Low Income Renter     27108    102544   -0.0151 -0.0270  -0.0032   0.0272
#
# ====================================================================================================
# OVERALL SUMMARY - ALL SPECIES GROUPBY COMPARISON
# ====================================================================================================
#
# Benzene:
# percentile            group1                group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25 Low Income Renter Not Low Income Renter    0.1140  0.0999   0.1287      0.0  negligible
#        p50 Low Income Renter Not Low Income Renter    0.1776  0.1632   0.1933      0.0  negligible
#        p75 Low Income Renter Not Low Income Renter    0.1957  0.1809   0.2108      0.0  negligible
#        p90 Low Income Renter Not Low Income Renter    0.1994  0.1854   0.2138      0.0  negligible
#        p95 Low Income Renter Not Low Income Renter    0.1968  0.1831   0.2112      0.0  negligible
#        p99 Low Income Renter Not Low Income Renter    0.1545  0.1409   0.1689      0.0  negligible
#       p100 Low Income Renter Not Low Income Renter   -0.0826 -0.0938  -0.0706      0.0  negligible
#
# Styrene:
# percentile            group1                group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25 Low Income Renter Not Low Income Renter    0.0082 -0.0017   0.0195   0.2278  negligible
#        p50 Low Income Renter Not Low Income Renter    0.0128  0.0022   0.0244   0.0617  negligible
#        p75 Low Income Renter Not Low Income Renter   -0.0003 -0.0113   0.0108   0.9603  negligible
#        p90 Low Income Renter Not Low Income Renter   -0.0579 -0.0689  -0.0474   0.0000  negligible
#        p95 Low Income Renter Not Low Income Renter   -0.0578 -0.0694  -0.0468   0.0000  negligible
#        p99 Low Income Renter Not Low Income Renter   -0.0281 -0.0404  -0.0156   0.0000  negligible
#       p100 Low Income Renter Not Low Income Renter   -0.0559 -0.0679  -0.0444   0.0000  negligible
#
# Ethylene Oxide:
# percentile            group1                group2  cohens_d  ci_low  ci_high  p_value effect_size
#        p25 Low Income Renter Not Low Income Renter   -0.0345 -0.0533  -0.0171   0.0000  negligible
#        p50 Low Income Renter Not Low Income Renter   -0.0327 -0.0495  -0.0158   0.0000  negligible
#        p75 Low Income Renter Not Low Income Renter   -0.1008 -0.1128  -0.0884   0.0000  negligible
#        p90 Low Income Renter Not Low Income Renter   -0.1048 -0.1145  -0.0943   0.0000  negligible
#        p95 Low Income Renter Not Low Income Renter   -0.0248 -0.0354  -0.0136   0.0003  negligible
#        p99 Low Income Renter Not Low Income Renter    0.0066 -0.0052   0.0199   0.3356  negligible
#       p100 Low Income Renter Not Low Income Renter   -0.0151 -0.0270  -0.0032   0.0272  negligible

# %%
# Compare ownership groups for Benzene at 1km resolution
species_list = ['Benzene','Styrene','Ethylene Oxide']  # Add more species as available in your data
percentile_list = ['p25','p50','p75','p90','p95','p99','p100']
results_lowrenter_4km = compare_groupby_anova(
    hua_ari_df, species_list, percentiles=percentile_list, 
    groupby_variable='Low Income Renter Status', resolution='4km', 
    matched_cases_only=True, verbose=False
)

# %%
results_lowrenter_4km.head(5)
# Out:
#    species percentile resolution          groupby_variable  matched_cases  \
# 0  Benzene        p25        4km  Low Income Renter Status           True
# 1  Benzene        p50        4km  Low Income Renter Status           True
# 2  Benzene        p75        4km  Low Income Renter Status           True
# 3  Benzene        p90        4km  Low Income Renter Status           True
# 4  Benzene        p95        4km  Low Income Renter Status           True
#
#               group1                 group2  n_group1  n_group2  mean_group1  \
# 0  Low Income Renter  Not Low Income Renter     31569    136545     0.011930
# 1  Low Income Renter  Not Low Income Renter     31569    136545     0.023542
# 2  Low Income Renter  Not Low Income Renter     31569    136545     0.044688
# 3  Low Income Renter  Not Low Income Renter     31569    136545     0.075730
# 4  Low Income Renter  Not Low Income Renter     31569    136545     0.101702
#
#    mean_group2  f_statistic        p_value  cohens_d    ci_low   ci_high  \
# 0     0.011427   338.309004   1.767655e-75  0.114866  0.101214  0.128668
# 1     0.022251   912.378351  6.883252e-200  0.188634  0.174829  0.202785
# 2     0.041731  1612.523109   0.000000e+00  0.250776  0.236885  0.265031
# 3     0.070598  1863.900707   0.000000e+00  0.269616  0.256148  0.283891
# 4     0.095549  1715.714044   0.000000e+00  0.258676  0.245796  0.272144
#
#   effect_size        welch_p
# 0  negligible   8.292526e-62
# 1  negligible  6.129515e-159
# 2       small  5.550401e-276
# 3       small   0.000000e+00
# 4       small   0.000000e+00

# %%
# Create the effect size plot using both DataFrames
fig_effect_sizes = plot_effect_sizes_by_percentile(
    results_multi_species, 
    programname=programname,
    title_description = "1km vs 4km Resolution",
    save_plot=True
)
# Out:
# Effect size plot saved to: ip1_3bv2_peopleair\ip1_3bv2_peopleair_benzene_ethylene_oxide_styrene_effect_sizes_by_percentile.png

# %%
# Create the effect size plot using both DataFrames
fig_effect_sizes = plot_effect_sizes_by_percentile(
    results_ownership_1km, 
    programname=programname,
    title_description = "1km Ownership",
    save_plot=True
)
# Out:
# Effect size plot saved to: ip1_3bv2_peopleair\ip1_3bv2_peopleair_benzene_ethylene_oxide_styrene_effect_sizes_by_percentile.png

# %%
# Create the effect size plot using both DataFrames
fig_effect_sizes = plot_effect_sizes_by_percentile(
    results_ownership_4km, 
    programname=programname,
    title_description = "4km Ownership",
    save_plot=True
)
# Out:
# Effect size plot saved to: ip1_3bv2_peopleair\ip1_3bv2_peopleair_benzene_ethylene_oxide_styrene_effect_sizes_by_percentile.png

# %%
# Create the effect size plot using both DataFrames
fig_effect_sizes = plot_effect_sizes_by_percentile(
    results_lowrenter_1km, 
    programname=programname,
    title_description = "1km Low Income Renter",
    save_plot=True
)
# Out:
# Effect size plot saved to: ip1_3bv2_peopleair\ip1_3bv2_peopleair_benzene_ethylene_oxide_styrene_effect_sizes_by_percentile.png

# %%
# Create the effect size plot using both DataFrames
fig_effect_sizes = plot_effect_sizes_by_percentile(
    results_lowrenter_4km, 
    programname=programname,
    title_description = "4km Low Income Renter",
    save_plot=True
)
# Out:
# Effect size plot saved to: ip1_3bv2_peopleair\ip1_3bv2_peopleair_benzene_ethylene_oxide_styrene_effect_sizes_by_percentile.png

# %%
# Example usage: Create plot for Benzene (all available data)
fig_benzene = create_species_percentiles_comparison_plot(
    hua_ari_df, 'Benzene', programname, save_plot=True
)

# Example usage: Create plot for Benzene (matched cases only)
fig_benzene_matched = create_species_percentiles_comparison_plot(
    hua_ari_df, 'Benzene', programname, save_plot=True, matched_cases_only=True
)

# %%
# Example usage: Create plot for Benzene (all available data)
fig_styrene = create_species_percentiles_comparison_plot(
    hua_ari_df, 'Styrene', programname, save_plot=True
)

# Example usage: Create plot for Benzene (matched cases only)
fig_styrene_matched = create_species_percentiles_comparison_plot(
    hua_ari_df, 'Styrene', programname, save_plot=True, matched_cases_only=True
)

# %%
# Example usage: Create plot for Benzene (all available data)
fig_ethylene_oxide = create_species_percentiles_comparison_plot(
    hua_ari_df, 'Ethylene Oxide', programname, save_plot=True
)

# Example usage: Create plot for Benzene (matched cases only)
fig_ethylene_oxide_matched = create_species_percentiles_comparison_plot(
    hua_ari_df, 'Ethylene Oxide', programname, save_plot=True, matched_cases_only=True
)

# %% [markdown]
# Summary of methods from MS Copilot Auto LLM selection
#
# ### Version 1: Academic Journal Audience
# #### Title: Assessing Ownership-Based Disparities in Air Pollution Exposure Across Distributional Percentiles
# #### Summary:
# To evaluate whether disparities in air pollution exposure between owner-occupied and renter-occupied housing units vary across the exposure distribution, we computed standardized mean differences (Cohen’s d) at multiple percentiles (p25, p50, p75, p90) of modeled benzene concentrations. This approach moves beyond a single summary statistic (e.g., mean or p90) to capture potential heterogeneity in disparities at higher exposure levels, which are often more relevant for health risk assessment. Effect sizes were plotted against percentiles to visualize trends, providing insight into whether ownership-related differences amplify in the upper tail of the distribution. This method complements traditional ANOVA by emphasizing practical significance and distributional equity rather than relying solely on p-values, which can be misleading in large samples.
#
# ### Version 2: Community Decision Makers (No Statistical Background)
# #### Title: Looking at Pollution Differences Where It Matters Most
# #### Summary:
# Instead of just comparing average pollution levels between homeowners and renters, we looked at different points in the pollution range—from typical levels to the highest levels people experience. This helps us see if renters face bigger differences when pollution is at its worst. We measured the size of the gap at each point and made a simple chart showing whether the gap grows as pollution gets higher. This approach focuses on real-world impact: even if overall differences are small, renters might still be more exposed in the most polluted areas, which is important for health and fairness.
